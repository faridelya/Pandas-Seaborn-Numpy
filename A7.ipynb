# %% [markdown]
# <a href="https://colab.research.google.com/github/faridelya/Pandas-Seaborn-Numpy/blob/main/A7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ef30052-a4b9-457e-b519-c72b10c2ef8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ef30052-a4b9-457e-b519-c72b10c2ef8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd 
import seaborn as sn
import matplotlib.pyplot as plt
import io



pd.set_option('display.max_rows', 3000)
pd.set_option('display.max_columns', 37)

# %%
cnty = pd.read_csv(io.BytesIO(uploaded['us_county_data.csv']))
cnty
# Out:
#                    NAME STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP   FIPS  \
# 0        Autauga County    Alabama         AL           1           1   1001
# 1        Baldwin County    Alabama         AL           1           3   1003
# 2        Barbour County    Alabama         AL           1           5   1005
# 3           Bibb County    Alabama         AL           1           7   1007
# 4         Blount County    Alabama         AL           1           9   1009
# ...                 ...        ...        ...         ...         ...    ...
# 3099  Sweetwater County    Wyoming         WY          56          37  56037
# 3100       Teton County    Wyoming         WY          56          39  56039
# 3101       Uinta County    Wyoming         WY          56          41  56041
# 3102    Washakie County    Wyoming         WY          56          43  56043
# 3103      Weston County    Wyoming         WY          56          45  56045
#
# ...

# %% [markdown]
# # **Q1**
# ### **Generate a box plot showing the distribution of county-level median income(“med_income”) for all counties in the dataset.**

# %%
fig, ax = plt.subplots(figsize=(35,10))
b = sn.boxplot(data=cnty, x='med_income' , ax=ax);
b.axes.set_title("Box Plot",fontsize=50)
b.set_xlabel("median county",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # **Q2**
# ### **Generate a grouped box plot showing the distribution of county-level median income (“med_income”) grouped by subregion of the country (“SUB_REGION”) for all counties in the dataset.**

# %%
fig, ax = plt.subplots(figsize=(35,10))
b = sn.boxplot(data=cnty, x='med_income' ,y='SUB_REGION' , hue="SUB_REGION",ax=ax, dodge=False);
b.axes.set_title("Box Plot",fontsize=50)
b.set_xlabel("median county income",fontsize=20)
b.set_ylabel("Sub Region",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # **Q3**
# ## **Generate a histogram showing the distribution of county-level median income(“med_income”) for all counties in the dataset**

# %%
fig, ax = plt.subplots(figsize=(35,10))
b = sn.histplot(data=cnty,  x='med_income', y=None, hue=None, stat='count', bins='auto',  element='bars', ax=ax,);
b.axes.set_title("Box Plot",fontsize=50)
b.set_xlabel("median county income",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # **Q4**
# ## : **Generate a kernel density plot showing the distribution of county-level median income (“med_income”) for all counties in the dataset**

# %%
fig, ax = plt.subplots(figsize=(35,10))
b = sn.histplot(data=cnty,  x='med_income',kde=True,  ax=ax,);
b.axes.set_title("Histogram with KDE",fontsize=50)
b.set_xlabel("median county income",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(35,10))
sn.kdeplot(data=cnty,  x='med_income',ax=ax);

# %% [markdown]
# # **Q5**
# ## **Generate a histogram showing the distribution of county-level percent forest cover (“per_for”) for only counties occurring in the West North Central (“W N Cen”) subregion (“SUB_REGION”)**

# %%
wn_cen = cnty[cnty['SUB_REGION'] == 'W N Cen']
fig, ax = plt.subplots(figsize=(35,10))
b = sn.histplot(data=wn_cen,  x='per_for', hue='SUB_REGION',kde=True,  ax=ax,);
b.axes.set_title("Histogram",fontsize=50)
b.set_xlabel("percent forest cover in  West North Central",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # **Q6**
# ## **Generate grouped kernel density plots showing the distribution of countylevel percent cropland (“per_crop”) for only counties occurring in the West North Central (“W N Cen”), Pacific (“Pacific”), and Mountain (“Mtn”) subregions (“SUB_REGION”). Each subregion should have a separate density plot in the graph  space**

# %%
wn_cen =cnty[cnty['SUB_REGION'] == "W N Cen" ]
pf =cnty[ cnty['SUB_REGION'] ==  'Pacific']
mtn = cnty[cnty['SUB_REGION'] == 'Mtn']
wn_cen_pf = pd.concat([wn_cen,pf,mtn])

fig, ax = plt.subplots(figsize=(35,10))
b = sn.kdeplot(data=wn_cen_pf,  x='per_crop', hue='SUB_REGION',ax=ax);
b.axes.set_title("KDE",fontsize=50)
b.set_xlabel("PERCENT CROPLAND ",fontsize=20)
b.set_ylabel("Density",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(35,10))
sn.kdeplot(
   data=wn_cen_pf, x="per_crop", hue="SUB_REGION",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,ax=ax
);

# %% [markdown]
# # **Q7**
# ## **Generate a dot plot showing the mean percent crop land (“per_crop”) for only counties occurring in the West North Central (“W N Cen”), Pacific (“Pacific”), and Mountain (“Mtn”) subregions (“SUB_REGION”). Three data points should beprovided: one for each subregion.**

# %%
cnty["SUB_REGION"].unique()
# Out:
# array(['E S Cen', 'Mtn', 'W S Cen', 'Pacific', 'N Eng', 'S Atl',
#        'E N Cen', 'W N Cen', 'Mid Atl'], dtype=object)

# %%
wn_cen_pf =wn_cen_pf.groupby('SUB_REGION')['per_crop'].mean()
wn_cen_pf
# Out:
# SUB_REGION
# Mtn         9.590028
# Pacific    11.782296
# W N Cen    46.346205
# Name: per_crop, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,10))
b= sn.scatterplot(data=wn_cen_pf, x=[9.5,11.7,46.34], y=["Mtn","Pacific","W N Cen"] ,hue="SUB_REGION", s=500);
b.axes.set_title("Dot Plot for 3 Data point of mean percentage of per crop",fontsize=30)
b.set_xlabel("PERCENT CROPLAND ",fontsize=20)
b.set_ylabel("Region",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # **Q8**

# %%
 # 1st standar deviation 68% distribution from mean
import numpy as np
 
wn_cen =cnty[cnty['SUB_REGION'] == "W N Cen" ]
pf =cnty[ cnty['SUB_REGION'] ==  'Pacific']
mtn = cnty[cnty['SUB_REGION'] == 'Mtn']
wn_cen_pf = pd.concat([wn_cen,pf,mtn])
fig, ax = plt.subplots(figsize=(20,10))
 b =sn.barplot(x="SUB_REGION", y='per_crop', data=wn_cen_pf, estimator=np.mean, ci=68, capsize=.68, color='lightblue')
b.axes.set_title("adding error bar to mean percent per crop land",fontsize=30)
b.set_xlabel("Region ",fontsize=20)
b.set_ylabel("Percentage",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(30,13))
sn.pointplot(data=wn_cen_pf, x='SUB_REGION', y='per_crop', hue='SUB_REGION', errorbar=("sd",68 ),ax=ax);

# %% [markdown]
# # **Q9**
# ## Create a scatter plot showing the relationship between mean elevation(“dem”) and mean county-level average annual temperature (“tempmn”) for all counties in the country.

# %%
fig, ax = plt.subplots(figsize=(38,12))
b = sn.scatterplot(
    data=cnty, x="dem", y="tempmn", 
    s=200, );

b.axes.set_title("Scatter plot relationship btw dem and tempmn",fontsize=30)
b.set_xlabel("dem ",fontsize=20)
b.set_ylabel("tempmn",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # Q10
# ## Replicate Graph 9 but now differentiate the subregions (“SUB_REGION”) by using different colors or point symbols. In other words, all counties in the amesubregion should have the same color or symbol applied.

# %%
fig, ax = plt.subplots(figsize=(38,12))
b = sn.scatterplot(
    data=cnty, x="dem", y="tempmn", 
    s=100, hue='SUB_REGION' ,palette="deep");

b.axes.set_title("Scatter plot relationship btw dem and tempmn",fontsize=30)
b.set_xlabel("dem ",fontsize=20)
b.set_ylabel("tempmn",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # **Q11**
# ##  Create a scatter plot showing the relationship between mean elevation (“dem”) and mean county-level average annual temperature (“tempmn”) for only counties occurring in the West North Central (“W N Cen”), Pacific (“Pacific”), andMountain (“Mtn”) subregions. Differentiate the subregions (“SUB_REGION”) by using different colors or point symbols. In other words, all counties in the same subregion should have the same color or symbol applied

# %%
fig, ax = plt.subplots(figsize=(38,12))
b = sn.scatterplot(
    data=wn_cen_pf, x="dem", y="tempmn", 
    s=100, hue='SUB_REGION' ,palette=sn.color_palette("husl", 3));

b.axes.set_title("Scatter plot relationship btw dem and tempmn",fontsize=30)
b.set_xlabel("dem ",fontsize=20)
b.set_ylabel("tempmn",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# # **Q12**
# ## Generate a grouped box plot showing the distribution of mean county elevation (“dem”) grouped by state (“STATE_NAME” or “STATE_ABBR”) for only counties occurring in Florida, Colorado, Montana, and Nebraska.

# %%
fig, ax = plt.subplots(figsize=(35,30))
b = sn.boxplot(data=cnty, x='dem' ,y='STATE_NAME' , hue="STATE_NAME",ax=ax, dodge=False);
b.axes.set_title("Box Plot",fontsize=50)
b.set_xlabel("median county income",fontsize=20)
b.set_ylabel("Sub Region",fontsize=20)
b.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# #  Graph 13: Generate a scatterplot for only counties occurring in Vermont to compare the population density (“POP_SQMI”) and mean county-level average annual temperature (“tempmn”). Label each point in the plot with the county name.

# %%
vermt_cunty = cnty[cnty['STATE_NAME'] == 'Vermont']
fig, ax = plt.subplots(figsize=(30,10))
b = sn.scatterplot(
    data=vermt_cunty, x='POP_SQMI', y="tempmn", 
    s=400, hue='NAME' ,palette='deep');

b.axes.set_title("Scatter plot relationship btw POP_SQMI and tempmn",fontsize=30)
b.set_xlabel("POP_SQMI ",fontsize=20)
b.set_ylabel("tempmn",fontsize=20)
b.tick_params(labelsize=15)

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.08, point['y'], str(point['val']))

label_point(vermt_cunty.POP_SQMI, vermt_cunty.tempmn, vermt_cunty.NAME, plt.gca()) 
plt.show()

# %%
cnty.columns
# Out:
# Index(['NAME', 'STATE_NAME', 'STATE_ABBR', 'STATE_FIPS', 'COUNTY_FIP', 'FIPS',
#        'POPULATION', 'POP_SQMI', 'SQMI', 'SUB_REGION', 'med_income',
#        'households', 'per_desk_lap', 'per_smartphone', 'per_no_comp',
#        'per_internet', 'per_broadband', 'per_no_internet', 'dem', 'precip',
#        'tempmn', 'tempmin', 'tempmax', 'dptmn', 'vpdmin', 'vpdmax', 'sol',
#        'per_for', 'per_dev', 'per_wet', 'per_crop', 'per_past_grass',
#        'strm_length', 'strm_den', 'per_karst', 'rail_den', 'road_den'],
#       dtype='object')

# %%
cnty['STATE_NAME'].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida',
#        'Georgia', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
vermt_cunty = cnty[cnty['STATE_NAME'] == 'Vermont']
# Out:
#                    NAME STATE_NAME STATE_ABBR  STATE_FIPS  COUNTY_FIP   FIPS  \
# 2772     Addison County    Vermont         VT          50           1  50001
# 2773  Bennington County    Vermont         VT          50           3  50003
# 2774   Caledonia County    Vermont         VT          50           5  50005
# 2775  Chittenden County    Vermont         VT          50           7  50007
# 2776       Essex County    Vermont         VT          50           9  50009
# 2777    Franklin County    Vermont         VT          50          11  50011
# 2778  Grand Isle County    Vermont         VT          50          13  50013
# 2779    Lamoille County    Vermont         VT          50          15  50015
# 2780      Orange County    Vermont         VT          50          17  50017
# 2781     Orleans County    Vermont         VT          50          19  50019
# 2782     Rutland County    Vermont         VT          50          21  50021
# ...
